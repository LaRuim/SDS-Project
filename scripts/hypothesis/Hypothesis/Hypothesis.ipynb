# %%
import pandas as pd
import scipy.stats
import numpy as np

# %%
strikers = pd.read_csv('/content/drive/My Drive/Colab Notebooks/Nihal/Hypothesis/strikers.csv')

# %%
strikers['ethnicity'].replace('', np.nan, inplace=True)
strikers.dropna(subset=['ethnicity'], inplace=True)

# %% [markdown]
# **Hypothesis 1**<br>
# H0: Asians are just as good as Caucasians when it comes to mental attributes. <br>
# H1: Caucasians are better than Asians when it comes to mental attributes. <br>

# %%
eth_list = list(strikers['ethnicity'])

# %%
freq = dict()
for i in eth_list:
    if i not in freq.keys():
        freq[i] = 0
    freq[i] += 1

# %%
strikers['mentality_composure']
# Out:
# 0      18
# 1      16
# 2      17
# 3      17
# 4      18
#        ..
# 854     9
# 857     9
# 858     9
# 860     8
# 861     9
# Name: mentality_composure, Length: 819, dtype: int64

# %%
print(freq)
# Out:
# {'Caucasian': 544, 'Black': 203, 'Middle-eastern': 37, 'Asian': 35}

# %%
asn = strikers[strikers['ethnicity'] == 'Asian']
csn = strikers[strikers['ethnicity'] == 'Caucasian']

# %%
asn
# Out:
#      Unnamed: 0  index  ... mentality_penalties  mentality_composure
# 81           81     81  ...                  10                   14
# 147         147    147  ...                  13                   15
# 150         150    150  ...                  14                   12
# 237         237    237  ...                   9                   14
# 249         249    249  ...                  14                   13
# 255         255    255  ...                  14                   14
# 278         278    278  ...                   8                   15
# 287         287    287  ...                  14                   14
# 306         306    306  ...                  11                   14
# 345         345    345  ...                  12                   12
# 346         346    346  ...                  13                   13
# 415         415    415  ...                  13                   14
# 454         454    454  ...                  16                   13
# 462         462    462  ...                  12                   13
# 465         465    465  ...                   8                   13
# 478         478    478  ...                  13                   13
# 489         489    489  ...                  11                   11
# 511         511    511  ...                  14                   10
# 514         514    514  ...                  10                   12
# 544         544    544  ...                  12                   13
# 604         604    604  ...                   8                   12
# 614         614    614  ...                  12                   11
# 628         628    628  ...                  12                   14
# 663         663    663  ...                   8                   13
# 680         680    680  ...                  13                    9
# 696         696    696  ...                  13                   10
# 713         713    713  ...                  13                   10
# 720         720    720  ...                   9                   11
# 726         726    726  ...                  12                   12
# 750         750    750  ...                   9                   12
# 761         761    761  ...                  12                    9
# 765         765    765  ...                   9                   11
# 789         789    789  ...                  10                   12
# 813         813    813  ...                  11                   10
# 844         844    844  ...                  12                   10
#
# [35 rows x 34 columns]

# %%
csn
# Out:
#      Unnamed: 0  index  ... mentality_penalties  mentality_composure
# 0             0      0  ...                  16                   18
# 2             2      2  ...                  16                   17
# 3             3      3  ...                  17                   17
# 4             4      4  ...                  18                   18
# 5             5      5  ...                  17                   16
# ..          ...    ...  ...                 ...                  ...
# 852         852    852  ...                  10                    9
# 853         853    853  ...                  10                   11
# 857         857    857  ...                  11                    9
# 858         858    858  ...                  11                    9
# 861         861    861  ...                  12                    9
#
# [544 rows x 34 columns]

# %%
ma = np.array((asn['mentality_composure']))
maMean = ma.mean()
maStd = ma.std()

# %%
mc = np.array((csn['mentality_composure']))
mcMean = mc.mean()
mcStd = mc.std()

# %%
print(maMean, maStd)
# Out:
# 12.228571428571428 1.64030858221798

# %%
print(mcMean, mcStd)
# Out:
# 12.9375 1.9392781214547183

# %%
len(mc)
# Out:
# 544

# %%
len(ma)
# Out:
# 35

# %%
z_score = (maMean - mcMean)/(maMean/len(ma))

# %%
print(z_score)
# Out:
# -2.029059579439255

# %%
p_values = scipy.stats.norm.sf(abs(z_score))

# %%
p_values
# Out:
# 0.021226111129020193

# %% [markdown]
# As you can see the probability value is very low, hence we disproved H0.

# %% [markdown]
# **Hypothesis 2**<br>
# H0: Blacks are better than Asians when it comes to physical attributes. <br>
# H1: Asians are just as good as Blacks when it comes to physical attributes.

# %%
blc = strikers[strikers['ethnicity'] == 'Black']

# %%
blc
# Out:
#      Unnamed: 0  index  ... mentality_penalties  mentality_composure
# 1             1      1  ...                  14                   16
# 8             8      8  ...                  16                   17
# 10           10     10  ...                  16                   17
# 16           16     16  ...                  15                   16
# 22           22     22  ...                  16                   15
# ..          ...    ...  ...                 ...                  ...
# 826         826    826  ...                  11                    9
# 841         841    841  ...                  11                   11
# 848         848    848  ...                  11                   11
# 850         850    850  ...                   7                   10
# 860         860    860  ...                  11                    8
#
# [203 rows x 34 columns]

# %%
ma1 = np.array((asn['attacking_finishing']))
ma1Mean = ma1.mean()
ma1Std = ma1.std()

# %%
bl = np.array((blc['attacking_finishing']))
blMean = bl.mean()
blStd = bl.std()

# %%
print(ma1Mean, ma1Std)
# Out:
# 65.62342857142858 6.340579938710944

# %%
print(blMean, blStd)
# Out:
# 71.36059113300493 7.302634968494186

# %%
len(ma1)
# Out:
# 35

# %%
len(bl)
# Out:
# 203

# %%
z_score1 = (ma1Mean - blMean)/(ma1Mean/len(ma1))

# %%
p_values = scipy.stats.norm.sf(abs(z_score1))

# %%
p_values
# Out:
# 0.0011070792786690203

# %% [markdown]
# As you can see the probability value is very low, hence we disproved H0.
