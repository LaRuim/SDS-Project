# %%
import pandas as pd 
data = pd.read_csv("../../../datasets/Full/players_20.csv") #encoding='cp1252')
data
# Out:
#        Unnamed: 0          short_name  age  height_cm  weight_kg  \
# 0               0            L. Messi   32      169.9       71.6
# 1               1   Cristiano Ronaldo   34      187.0       82.6
# 2               2           Neymar Jr   27      174.8       67.5
# 3               3           E. Hazard   28      174.9       74.2
# 4               4        K. De Bruyne   28      180.7       69.8
# ...           ...                 ...  ...        ...        ...
# 18273       18273           N. Morley   18      177.9       59.8
# 18274       18274          V. Storsve   17      185.4      -64.7
# 18275       18275  G. Sykes-Kenworthy   19      181.9       77.9
# 18276       18276          H. Sveijer   17      185.3       70.5
# 18277       18277           P. Martin   20      188.0       84.0
#
#                nationality  ethnicity  overall preferred_foot  weak_foot  ...  \
# 0                Argentina  Caucasian       94           Left  Excellent  ...
# 1                 Portugal  Caucasian       93          Right  Excellent  ...
# 2                   Brazil      Black       92          Right  Masterful  ...
# 3                  Belgium  Caucasian       91          Right  Excellent  ...
# 4                  Belgium  Caucasian       91          Right  Masterful  ...
# ...                    ...        ...      ...            ...        ...  ...
# 18273              England      Black       48          Right    Average  ...
# 18274               Norway  Caucasian       48          Right    Average  ...
# 18275              England  Caucasian       48          Right       Good  ...
# 18276                  NaN        NaN       48          Right    Average  ...
# 18277  Republic of Ireland  Caucasian       48          Right       Poor  ...
#
#       power_long_shots mentality_aggression mentality_interceptions  \
# 0                   18                    9                       8
# 1                   18                   12                       5
# 2                   16                   10                       7
# 3                   16                   10                       8
# 4                   18                   15                      12
# ...                ...                  ...                     ...
# 18273                4                    8                      10
# 18274                1                    3                       2
# 18275                1                    4                       1
# 18276                1                    3                       1
# 18277                1                    3                       2
#
#        mentality_positioning  mentality_vision  mentality_penalties  \
# 0                         18                18                   15
# 1                         19                16                   17
# 2                         17                18                   18
# 3                         17                17                   17
# 4                         17                18                   15
# ...                      ...               ...                  ...
# 18273                      4                 5                    7
# 18274                      0                 5                    2
# 18275                      1                 6                    3
# 18276                      1                 4                    2
# 18277                      1                 4                    2
#
#        mentality_composure  defending_marking  defending_standing_tackle  \
# 0                       19              33.28                      37.38
# 1                       19              28.01                      31.64
# 2                       18              26.81                      25.55
# 3                       18              34.44                      26.62
# 4                       18              68.08                      57.65
# ...                    ...                ...                        ...
# 18273                    8              46.10                      50.72
# 18274                    4               8.12                      14.28
# 18275                    5               9.81                      13.16
# 18276                    4               7.95                       9.53
# 18277                    6               5.53                      11.64
#
#        defending_sliding_tackle
# 0                         25.76
# 1                         23.75
# 2                         29.00
# 3                         21.97
# 4                         51.15
# ...                         ...
# 18273                    -46.60
# 18274                     10.96
# 18275                     12.18
# 18276                     10.33
# 18277                     10.74
#
# [18278 rows x 42 columns]

# %%
import pandas as pd 
centre_backs = pd.read_csv("../../../datasets/Positionwise/centre_backs.csv") 
free_roamers = pd.read_csv("../../../datasets/Positionwise/free_roamers.csv")
full_backs = pd.read_csv("../../../datasets/Positionwise/full_backs.csv")
midfielders = pd.read_csv("../../../datasets/Positionwise/midfielders.csv")
strikers = pd.read_csv("../../../datasets/Positionwise/strikers.csv")
wingers = pd.read_csv("../../../datasets/Positionwise/wingers.csv")

centre_backs.hist(column='overall')
free_roamers.hist(column='overall')
full_backs.hist(column='overall')
midfielders.hist(column='overall')
strikers.hist(column='overall')
wingers.hist(column='overall')
# Out:
# array([[<AxesSubplot:title={'center':'overall'}>]], dtype=object)

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt


centre_backs = pd.read_csv("../../../datasets/Positionwise/centre_backs.csv") 
free_roamers = pd.read_csv("../../../datasets/Positionwise/free_roamers.csv")
full_backs = pd.read_csv("../../../datasets/Positionwise/full_backs.csv")
midfielders = pd.read_csv("../../../datasets/Positionwise/midfielders.csv")
strikers = pd.read_csv("../../../datasets/Positionwise/strikers.csv")
wingers = pd.read_csv("../../../datasets/Positionwise/wingers.csv")

ax = plt.axes()

bp = plt.boxplot(centre_backs.height_cm, positions = [1], widths= 0.6)
bp = plt.boxplot(free_roamers.height_cm, positions = [2.3], widths = 0.6)
bp = plt.boxplot(full_backs.height_cm, positions = [3.5], widths = 0.6)
bp = plt.boxplot(midfielders.height_cm, positions = [4.6], widths = 0.6)
bp = plt.boxplot(strikers.height_cm, positions = [5.6], widths = 0.6)
bp = plt.boxplot(wingers.height_cm, positions = [6.6], widths = 0.6)

ax.set_xticklabels(['Centre_backs', 'Free_roamers', 'Full_backs', 'Midfielders', 'Strikers', 'Wingers'])
ax.set_xticks([1, 2.3, 3.5, 4.6, 5.6, 6.6])
# Out:
# [<matplotlib.axis.XTick at 0x1224839e8>,
#  <matplotlib.axis.XTick at 0x1224835c0>,
#  <matplotlib.axis.XTick at 0x122483208>,
#  <matplotlib.axis.XTick at 0x1226b4a90>,
#  <matplotlib.axis.XTick at 0x1226b4f28>,
#  <matplotlib.axis.XTick at 0x1226c1400>]
